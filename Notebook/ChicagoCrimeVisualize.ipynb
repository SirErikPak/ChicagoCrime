# %% [markdown]
# ## Summary
#
#
# ### Overview of Indexed Crimes (2001–2025) [Jump to Indexed Crime](#Indexed)
#
# The provided plots highlight a strong concentration of peak crime activity during Quarter 3 (July–September), with nearly all listed offenses—ranging from property crimes like Burglary to violent crimes like Aggravated Battery, reaching their highest frequency during this period. Seasonally, July is the most common month for peak activity, particularly for violent incidents and arson.
#
# The timing of these offenses reveals a clear weekend effect. Sunday is the dominant day for high-risk violent crimes, including Homicide, Aggravated Assault, and Battery, most of which peak during the Late Night (12 AM – 3 AM) or Night (8 PM – 11 PM) windows. In contrast, property-focused crimes like Larceny and Burglary tend to peak on Fridays, shifting the timeframe to the Morning or Afternoon.
#
# Interestingly, while most crimes center around the warmer months of Q3, there are notable outliers in the timing of specific offenses. For instance, Motor Vehicle Theft and Robbery peak later in the year, in October, while Criminal Sexual Assault shows a peak in January. This suggests that while environmental factors, such as summer weather, correlate with an overall increase in crime, specific social or situational triggers influence the timing of property theft, and seasonal anomalies.
#
# ### Overview of Non-Indexed Crime (2001–2025) [Jump to Non-Indexed Crime](#NonIndexed)
#
# Non-Indexed crimes show different timing patterns than Indexed crimes because they are driven more by behavior and context than by seasons. Instead of peaking at a specific time, they tend to follow daily routines. Some crimes occur during business hours; others are more common at night, when social activity is high; and some occur late at night, when fewer people are around. Unlike Indexed crimes, which peak in the summer, these crimes are spread more evenly throughout the year. However, certain patterns still appear, for example, drug-related crimes peak in the spring, and weapons violations increase after COVID. Overall, these crimes are shaped more by human activity and environment than by seasonal trends.
#
# | Behavioral Profile | Peak Time           | Offense Types                                | Logic                                                                           |
# |:-------------------|:--------------------|:----------------------------------------------|:--------------------------------------------------------------------------------|
# | Institutional      | Morning / Afternoon | Embezzlement, Fraud, Stolen Property         | These follow business hours (banking, retail, and office operations).           |
# | Social/Regulatory  | Evening / Night     | Gambling, Liquor Laws, Prostitution, Weapons | These align with nightlife, social gatherings, and decreased visibility.        |
# | Disruptive         | Late Night          | Sex Offenses                                 | These occur during the highest levels of isolation or late-night vulnerability. |
#
#
# ### Point Detailed Summary of Crime Z‑Score Trends (2001–2025) [Jump to Z-Score Heatmap](#Heatmap)
#
# **Note:** The Z-scores (standardized values) for annual Chicago crime counts (by `FBI/UCR` offense) from 2001–2025, where $0$ represents the average frequency for that specific crime over the 25-year period. Positive values indicate years with higher-than-average activity, while negative values indicate years with lower-than-average activity.
#
#
# #### Key Trends:
# - Most of what is classified as a `traditional` crime shows a significant downward trend. For example, `Liquor Laws`, `Robbery`, `Theft`, `Prostitution`, `Vandalism`, and `Battery` all started with high positive scores in the early 2000s and have remained steadily negative (below average) for the last decade.
#
# - **The Fraud Pivot:** While most physical crimes decreased, Fraud shows an inverse correlation. It stayed well below average from 2001 to 2013, then spiked significantly in 2016 and remained high through the early 2020s, possibly due to a fundamental transition from physical risk (street crime) to digital opportunity (cyber-enabled fraud).
#
# - **Violent Crime Volatility:**
#     - **First wave homicide (2016–2018):** The homicide category saw a sharp increase to break out of its long negative trend, with positive Z‑score spikes that stand out from the broader decline in other violent crimes.
#     - **Second wave homicide (2020–2024):** After a brief dip, both crimes surge again during the post‑COVID period, with Weapons Violations in particular reaching some of the highest positive anomalies in the entire dataset while peaking in 2021 (2.02).
#     - **Aggravated Assault** hitting its lowest point in 2013 (-1.79) before climbing back to a peak in 2024 (1.45).
# - **Motor Vehicle Theft Spike**: This category saw a dramatic shift. After nearly two decades of decline (bottoming out at -1.38 in 2019), it spiked to 1.95 in 2023.
#
# - **2020 Anomalies:** The year 2020 shows extreme outliers, likely due to pandemic-related shifts. Disorderly Conduct and Larceny-Theft plummeted to historic lows, while Weapons Violations and Homicide spiked sharply.
#
#
# ### Police District (2001–2025) [Jump to District Plots](#DistrictPlot)
# This comparative analysis of data, which includes Indexed Crimes (serious, often violent or high-loss crimes) and Non-Indexed Crimes (quality-of-life, regulatory, or less severe offenses), aims to identify patterns in the distribution of Police Districts and incident volume.
#
# 1. Volume and Scale Comparison
# - The scale of incidents differs drastically between the two categories. While Indexed crimes include severe offenses like Homicide, the sheer volume of "Larceny - Theft" (Indexed) and "Simple Battery" (Non-Indexed) dominates the data.
#
# | Metric          | Indexed Crimes (Top Volume)                     | Non-Indexed Crimes (Top Volume)                 |
# |-----------------|--------------------------------------------------|-------------------------------------------------|
# | Highest Volume  | Larceny – Theft: 161,621 (Near North)           | Drug Abuse Violations: 138,150 (Harrison)       |
# | Second Highest  | Burglary: 39,429 (Chicago Lawn)                 | Simple Battery: 96,635 (Englewood)              |
# | Lowest Volume   | Involuntary Manslaughter: 11 (Deering)          | Stolen Property: 301 (Near West)               |
#
#
# 2. Geographic Hotspots
# - Certain police districts appear repeatedly across different crime types, suggesting "hub" areas for specific categories of illegal activity.
#     * The "High-Frequency" Districts
#         * Chicago Lawn: It is a hotspot for property crimes (Burglary, MV Theft) and Non-Indexed quality-of-life issues (Vandalism, Simple Assault).
#         * Harrison: The primary hub for Drug Abuse Violations (138,150) and Prostitution (11,505), while also leading in violent Indexed crimes like Homicide (1,429) and Aggravated Battery (21,611).
#         * Central & Near North: These districts account for the majority of financial and property-theft crimes. They lead in Larceny, Fraud, Embezzlement, and Forgery. This is likely due to the high density of retail, tourism, and business headquarters in these areas.
#
#
# 3. Crime Nature vs. District Type
# - There is a clear correlation between the "character" of the district and the type of crime reported:
#     * Commercial/Business Hubs (Central, Near North): High Larceny and Fraud, but almost entirely absent from the Top 3 lists for violent crimes like Homicide or Aggravated Battery.
#     * Residential/Industrial Areas (Englewood, Gresham, South Chicago): These districts consistently rank highest for Violent Indexed Crimes (Homicide, Assault) and Simple Battery.
#     * High-Enforcement Areas (Harrison, Austin): These districts show extremely high numbers of Drug Abuse Violations, which are often "officer-initiated" crimes (meaning the counts are influenced by police activity and enforcement focus).
#
#
# ### Neighborhood
#
# | **FBI Crime Type (Indexed)**                         | **Neighborhood** | **Count** |     | **FBI Crime Type (Non‑Indexed)**                 | **Neighborhood** | **Count** |
# |------------------------------------------------------|------------------|-----------|-----|--------------------------------------------------|------------------|-----------|
# | Aggravated Assault                                   | Austin           | 9,841     |     | Disorderly Conduct                               | Austin           | 4,658     |
# | Aggravated Battery                                   | Austin           | 15,313    |     | Drug Abuse Violations                            | Austin           | 97,521    |
# | Arson                                                | Austin           | 929       |     | Embezzlement                                     | Near North Side  | 201       |
# | Burglary                                             | South Shore      | 18,565    |     | Forgery and Counterfeiting                       | Loop             | 2,513     |
# | Criminal Sexual Assault                              | Austin           | 2,836     |     | Fraud                                            | Near North Side  | 27,025    |
# | Homicide – 1st or 2nd Degree                         | Austin           | 1,173     |     | Gambling                                         | Austin           | 2,478     |
# | Involuntary Manslaughter / Reckless Homicide         | Brighton Park    | 5         |     | Liquor Laws                                      | South Lawndale   | 798       |
# | Larceny – Theft                                      | Near North Side  | 118,738   |     | Miscellaneous Non‑Index Offenses                 | Austin           | 30,281    |
# | Motor Vehicle Theft                                  | Austin           | 21,673    |     | Offenses Against Family and Children             | Austin           | 1,011     |
# | Robbery                                              | Austin           | 21,044    |     | Prostitution                                     | Austin           | 8,488     |
# |                                                      |                  |           |     | Sex Offense – Criminal Sexual Abuse              | Austin           | 2,227     |
# |                                                      |                  |           |     | Simple Assault                                   | Austin           | 32,535    |
# |                                                      |                  |           |     | Simple Battery                                   | Austin           | 85,390    |
# |                                                      |                  |           |     | Stolen Property (Buy, Receive, Possess)          | Austin           | 156       |
# |                                                      |                  |           |     | Vandalism                                        | Austin           | 45,286    |
# |                                                      |                  |           |     | Weapons Violations                               | Austin           | 9,043     |
#
# Austin is the most crime-heavy neighborhood overall, leading in most categories of both Indexed and Non-Indexed crimes. It ranks highest in major violent offenses like assault, battery, homicide, robbery, and motor vehicle theft, as well as in several high-volume non-indexed crimes such as drug violations, simple assault, simple battery, and vandalism. The main exceptions are property and finance-oriented crimes: Burglary is highest on the South Shore, while Larceny–Theft is concentrated on the Near North Side, likely due to higher commercial and tourist activity. Financial crimes such as fraud, embezzlement, and forgery are also more common on the Near North Side and in the Loop, reflecting the area's business and retail density. Overall, Austin stands out as the primary hotspot for most crime types, while specialized economic and commercial crimes are concentrated in more business-heavy neighborhoods.
#
# ### Ward
#
# | **FBI Crime Type (Indexed)**                         | **Ward** | **Count** |     | **FBI Crime Type (Non‑Indexed)**                 | **Ward** | **Count** |
# |------------------------------------------------------|----------|-----------|-----|--------------------------------------------------|----------|-----------|
# | Aggravated Assault                                   | 28       | 7,060     |     | Disorderly Conduct                               | 28       | 3,759     |
# | Aggravated Battery                                   | 28       | 13,837    |     | Drug Abuse Violations                            | 28       | 86,319    |
# | Arson                                                | 28       | 588       |     | Embezzlement                                     | 42       | 334       |
# | Burglary                                             | 17       | 15,503    |     | Forgery and Counterfeiting                       | 42       | 3,592     |
# | Criminal Sexual Assault                              | 28       | 1,925     |     | Fraud                                            | 42       | 36,081    |
# | Homicide – 1st or 2nd Degree                         | 28       | 961       |     | Gambling                                         | 28       | 1,699     |
# | Involuntary Manslaughter / Reckless Homicide         | 12       | 7         |     | Liquor Laws                                      | 42       | 649       |
# | Larceny – Theft                                      | 42       | 161,989   |     | Miscellaneous Non‑Index Offenses                 | 03       | 24,985    |
# | Motor Vehicle Theft                                  | 06       | 16,533    |     | Offenses Against Family and Children             | 06       | 972       |
# | Robbery                                              | 28       | 15,697    |     | Prostitution                                     | 28       | 7,863     |
# |                                                      |          |           |     | Sex Offense – Criminal Sexual Abuse              | 02       | 1,474     |
# |                                                      |          |           |     | Simple Assault                                   | 28       | 22,527    |
# |                                                      |          |           |     | Simple Battery                                   | 28       | 61,425    |
# |                                                      |          |           |     | Stolen Property (Buy, Receive, Possess)          | 02       | 139       |
# |                                                      |          |           |     | Vandalism                                        | 28       | 30,932    |
# |                                                      |          |           |     | Weapons Violations                               | 28       | 7,480     |
#
# Ward-level patterns show a clear geographic divide in crime across Chicago. Ward 28, which includes Austin and West Garfield Park, is the primary hotspot for violent and street-level crime, leading most Indexed categories such as assault, battery, homicide, sexual assault, and robbery, as well as several Non-Indexed categories like drug violations, simple assault, and vandalism. In contrast, Ward 42, covering the Loop and Near North Side, dominates financially and property-driven offenses, leading in fraud, forgery, embezzlement, and larceny–theft, reflecting its dense business and commercial activity. Other wards show more specialized patterns: Ward 17 has the highest burglary rates, while Ward 06 has the highest motor vehicle theft rates. Overall, the data highlights a strong spatial split—violent and street crimes concentrated in Ward 28, and financial and commercial crimes concentrated in Ward 42—mirroring broader district-level differences between West Side and central/north downtown areas.
#
#
# ### Location Description
#
# | **FBI Crime Type (Indexed)**                         | **Crime Location Description** | **Count** |     | **FBI Crime Type (Non‑Indexed)**                 | **Crime Location Description**     | **Count** |
# |------------------------------------------------------|--------------------------------|-----------|-----|--------------------------------------------------|------------------------------------|-----------|
# | Aggravated Assault                                   | STREET                         | 47,526    |     | Disorderly Conduct                               | STREET                             | 26,301    |
# | Aggravated Battery                                   | STREET                         | 60,988    |     | Drug Abuse Violations                            | STREET                             | 271,584   |
# | Arson                                                | VEHICLE NON COMMERCIAL         | 3,929     |     | Embezzlement                                     | COMMERCIAL/BUSINESS OFFICE         | 397       |
# | Burglary                                             | RESIDENCE                      | 145,720   |     | Forgery and Counterfeiting                       | RESIDENCE                           | 9,373     |
# | Criminal Sexual Assault                              | RESIDENCE                      | 16,470    |     | Fraud                                            | RESIDENCE                           | 102,541   |
# | Homicide – 1st or 2nd Degree                         | STREET                         | 6,766     |     | Gambling                                         | SIDEWALK                            | 8,354     |
# | Involuntary Manslaughter / Reckless Homicide         | STREET                         | 80        |     | Liquor Laws                                      | SIDEWALK                            | 3,248     |
# | Larceny – Theft                                      | STREET                         | 484,097   |     | Miscellaneous Non‑Index Offenses                 | RESIDENCE                           | 163,902   |
# | Motor Vehicle Theft                                  | STREET                         | 337,219   |     | Offenses Against Family and Children             | RESIDENCE                           | 8,598     |
# | Robbery                                              | STREET                         | 99,652    |     | Prostitution                                     | STREET                             | 58,390    |
# |                                                      |                                |           |     | Sex Offense – Criminal Sexual Abuse              | RESIDENCE                           | 18,514    |
# |                                                      |                                |           |     | Simple Assault                                   | RESIDENCE                           | 167,163   |
# |                                                      |                                |           |     | Simple Battery                                   | APARTMENT                           | 308,206   |
# |                                                      |                                |           |     | Stolen Property (Buy, Receive, Possess)          | STREET                             | 1,159     |
# |                                                      |                                |           |     | Vandalism                                        | STREET                             | 349,263   |
# |                                                      |                                |           |     | Weapons Violations                               | STREET                             | 51,202    |
#
# The street environment is the main location for most Indexed crimes, with 7 out of 10 categories occurring most often there. This includes the highest-volume offenses such as larceny-theft, motor vehicle theft, assault, battery, robbery, and homicide. The main exceptions are burglary and criminal sexual assault, which occur most often in residences, reflecting more private and opportunity-based incidents.
#
# For Non-Indexed crimes, location patterns are more split between public and private spaces. Street settings are most common for offenses like drug violations, prostitution, and vandalism, while homes are more common for crimes such as fraud, simple assault, sexual abuse-related offenses, and family-related incidents. One unique case is simple battery, which occurs most often in apartments rather than standalone residences, suggesting a stronger link to incidents in multi-unit housing. Overall, Indexed crimes are more street-centered, while Non-Indexed crimes are divided between public activity and domestic environments.

# %% [markdown]
# ### Python Libraries Used

# %%
# libraries
import pandas as pd
import pyarrow as pa
import pyarrow.feather as feather
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# python source path
sys.path.append('../Src/')

# custom python
import plot
import utils
import zscore_anomaly

# Create a dictionary of versions
versions = {
    "Python": sys.version.split()[0],
    "Pandas": pd.__version__,
    "NumPy": np.__version__,
    "Matplotlib": plt.matplotlib.__version__,
    "Seaborn": sns.__version__,
    "Pyarrow": pa.__version__
}

# Display as a clean DataFrame
df_versions = pd.DataFrame(list(versions.items()), columns=['Library', 'Version'])
print(df_versions)

# display all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# reset options
# pd.reset_option('display.max_columns')

# Use a single Arrow string & int64 type instance to save memory
arrow_string = pd.ArrowDtype(pa.string())
# arrow_int64 = pd.ArrowDtype(pa.int64())
# arrow_bool = pd.ArrowDtype(pa.bool8())
# Out:
#       Library Version
# 0      Python  3.13.9
# 1      Pandas   2.3.3
# 2       NumPy   2.3.4
# 3  Matplotlib  3.10.7
# 4     Seaborn  0.13.2
# 5     Pyarrow  22.0.0

# %% [markdown]
# ### Read Data

# %%
# PyArrow's version of the 'arrow' backend
df_crime = feather.read_feather('../Data/crime_data.feather', memory_map=True, types_mapper=pd.ArrowDtype)
# display
df_crime.head()
# Out:
#   case_number                 date                     block  iucr  \
# 0   01G050460  2001-01-24 20:45:00      072XX S RIDGELAND AV  1811
# 1   03J493690  2003-07-12 17:00:00        075XX S DOBSON AVE  0890
# 2   04X245238  2004-12-13 21:15:00      006XX N RIDGEWAY AVE  2024
# 3   07C115980  2006-03-31 09:15:00  026XX N NARRAGANSETT AVE  0610
# 4   07HN36467  2007-05-25 14:51:00     022XX N LA CROSSE AVE  1812
#
#   primary_type                     description location_description arrest  \
# 0    NARCOTICS    POSS: CANNABIS 30GMS OR LESS             SIDEWALK   True
# 1        THEFT                   FROM BUILDING            APARTMENT  False
# 2    NARCOTICS             POSS: HEROIN(WHITE)             SIDEWALK   True
# 3     BURGLARY                  FORCIBLE ENTRY            APARTMENT  False
# 4    NARCOTICS  POSS: CANNABIS MORE THAN 30GMS            RESIDENCE   True
#
#   domestic  beat district sector  ward community_code          community_name  \
# ...

# %%
df_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8469443 entries, 0 to 8469442
# Data columns (total 31 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   case_number           string[pyarrow]
#  1   date                  timestamp[s][pyarrow]
#  2   block                 string[pyarrow]
#  3   iucr                  string[pyarrow]
#  4   primary_type          string[pyarrow]
#  5   description           string[pyarrow]
#  6   location_description  string[pyarrow]
#  7   arrest                bool[pyarrow]
#  8   domestic              bool[pyarrow]
#  9   beat                  string[pyarrow]
#  10  district              string[pyarrow]
#  11  sector                dictionary<values=string, indices=int8, ordered=0>[pyarrow]
#  12  ward                  string[pyarrow]
#  13  community_code        string[pyarrow]
#  14  community_name        string[pyarrow]
#  15  community_area        double[pyarrow]
#  16  fbi_code              string[pyarrow]
# ...

# %% [markdown]
# ### Visualize (2001 - 2025)

# %% [markdown]
# ### Plots

# %%
# Plot coordinates
df_plot = df_crime[['x_coordinate','y_coordinate','fbi_index_code']].dropna().copy()
# remove invalid coordinates
df_plot = df_plot.loc[df_plot.x_coordinate > 0]

# Figure Size
plt.figure(figsize=(10, 10))

# Plot
ax = sns.scatterplot(
    data=df_plot,
    x='x_coordinate',
    y='y_coordinate',
    hue='fbi_index_code',
    alpha=0.01,
    s=3
)
# Remove Ticks
ax.tick_params(left=False, bottom=False)
# legend
legend = ax.legend(
    title="Crime Indexed",
    loc="upper right",
    markerscale=6,
    frameon=True
)

# Force legend markers to be visible
for handle in legend.legend_handles:
    handle.set_alpha(1)
    if hasattr(handle, "set_sizes"):  # safety for non-scatter handles
        handle.set_sizes([80])

plt.title("Crime Locations")
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
# Save the figure with high resolution and tight cropping
plt.savefig("../Image/scatter_crime_plot.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Yearly (2001-2025)

# %%
# for plot
pivot_year = utils.make_crime_year_crosstab(df_crime,  'year', 'fbi_code_desc')
# plot
plot.stacked_bar_plot(pivot_year, title='(2001-2025)', figsize=(16,8))
# for plot
melt_year = utils.melt_pivot_for_plotting(pivot_year, 'fbi_code_desc', 'year')
# plot
plot.line_plot(melt_year,'fbi_code_desc',  'year', 'count', col_wrap=3, rotation=90, ha='center')

# %% [markdown]
# #### Time of Day (2001 - 2025)
# <a id="Plots"></a>

# %% [markdown]
# | Interval (Inclusive, Exclusive) | Mathematical Notation | Label        | Hours Included    |
# |--------------------------------|----------------------|--------------|-------------------|
# | 1st: 0 to 4                    | \([0, 4)\)          | Late Night   | 0, 1, 2, 3       |
# | 2nd: 4 to 8                    | \([4, 8)\)          | Early Morning| 4, 5, 6, 7       |
# | 3rd: 8 to 12                   | \([8, 12)\)         | Morning      | 8, 9, 10, 11     |
# | 4th: 12 to 16                  | \([12, 16)\)        | Afternoon    | 12, 13, 14, 15   |
# | 5th: 16 to 20                  | \([16, 20)\)        | Evening      | 16, 17, 18, 19   |
# | 6th: 20 to 24                  | \([20, 24)\)        | Night        | 20, 21, 22, 23   |

# %%
# time label
time_labels = ['Late Night', 'Early Morning', 'Morning', 'Afternoon', 'Evening', 'Night']
# for plot
pivot_tod = utils.make_crime_year_crosstab(df_crime,  'time_of_day', 'fbi_code_desc')
# Reorder Time of Day
pivot_tod = pivot_tod.reindex(columns=time_labels)
# plot
plot.stacked_bar_plot(pivot_tod, title='Time Of Day', figsize=(16,8))

# Melt the dataframe for plotting
melt_tod = utils.melt_pivot_for_plotting(pivot_tod, 'fbi_code_desc', 'time_of_day')
# plot
plot.line_plot(melt_tod,'fbi_code_desc',  'time_of_day', 'count')

# %% [markdown]
# #### Day of Week (2001 - 2025)

# %%
# Month & Day of the Week
months = ['January', 'February', 'March', 'April', 'May', 'June', 
          'July', 'August', 'September', 'October', 'November', 'December']
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# for plot
pivot_week = utils.make_crime_year_crosstab(df_crime,  'day_of_week', 'fbi_code_desc')
# Reorder Mon - Sun chronologically
pivot_week = pivot_week.reindex(columns=days)
# plot
plot.stacked_bar_plot(pivot_week, title='Day of the Week', figsize=(16,8))
# for plot
melt_week = utils.melt_pivot_for_plotting(pivot_week, 'fbi_code_desc', 'day_of_week')
# plot
plot.line_plot(melt_week,'fbi_code_desc',  'day_of_week', 'count')

# %% [markdown]
# #### Month (2001 - 2025)

# %%
# for plot
pivot_month = utils.make_crime_year_crosstab(df_crime,  'month', 'fbi_code_desc')
# Reorder months chronologically
pivot_month = pivot_month.reindex(columns=months)
# plot
plot.stacked_bar_plot(pivot_month, title='Month',figsize=(16,10))
# for plot
melt_month = utils.melt_pivot_for_plotting(pivot_month, 'fbi_code_desc', 'month')
# plot
plot.line_plot(melt_month,'fbi_code_desc',  'month', 'count')

# %% [markdown]
# #### Quarterly (2001 - 2025)

# %%
# Define quarters once
quarter = ['Q1', 'Q2', 'Q3', 'Q4']
# for plot
pivot_qtr = utils.make_crime_year_crosstab(df_crime,  'quarter', 'fbi_code_desc')
# Reorder quarters chronologically
pivot_qtr = pivot_qtr.reindex(columns=quarter)

# plot
plot.stacked_bar_plot(pivot_qtr, title='Quarter')
# for plot
melt_qtr = utils.melt_pivot_for_plotting(pivot_qtr, 'fbi_code_desc', 'quarter')
# plot
plot.line_plot(melt_qtr,'fbi_code_desc',  'quarter', 'count', rotation=0, ha='center')

# %% [markdown]
# #### District Crimes (2001–2025)

# %%
# display NaNs
utils.any_nans(df_crime)
# Out:
# --- Missing Values Found (Total Rows: 8,469,443) ---
#                        Count Percentage
# community_code        483143    5.7045%
# community_name        483143    5.7045%
# community_area        483143    5.7045%
# ward                  481590    5.6862%
# location_description   15338    0.1811%
# x_coordinate            9405    0.1110%
# y_coordinate            9405    0.1110%
# latitude                9405    0.1110%
# longitude               9405    0.1110%
# district                  12    0.0001%
# sector                    12    0.0001%
# district_location         12    0.0001%

# %% [markdown]
# ##### Helper Function

# %%
def top_crime(data: pd.DataFrame, indexed: bool, top: int, 
              column: dict={"fbi_code_desc": "FBI Crime Type", "district_location": "Police District"}) -> None:

    # Get Keys
    it = iter(column)
    fbi_key = next(it, None)
    next_key  = next(it, None)

    data_out = (
        data.reset_index(name='count')
            .assign(**{fbi_key:  lambda d: d[fbi_key].astype(str),
                       next_key: lambda d: d[next_key].astype(str)})
            .sort_values([fbi_key, "count"], ascending=[True, False])
            .groupby(fbi_key).head(top).reset_index(drop=True)
            ).set_index([fbi_key, next_key]).sort_index(level=[0,1])
    
    # convert boolean argument
    flag = 'I' if indexed else 'N'
    txt  = 'Indexed' if indexed else 'Non-Indexed'
    mask = data_out.indexed.eq(flag)

    # Rename Index
    data_out = data_out.rename_axis(index=column)
    # Convert to DataFrame and rename the column 
    data_out = data_out.rename(columns={"count": "Incident Count"})

    print(f"{'-'*25} Top {top} {txt} Crime {'-'*25}\n")
    print(data_out.loc[mask].iloc[:, -1].apply(lambda x: f"{x:,}"))

# %% [markdown]
# **Missing District Not Aggregated**

# %%
# Current version of Arrow Bool cannot be mapped, factorized, grouped, or cast to an Arrow string
df_crime['fbi_index_code'] = df_crime['fbi_index_code'].astype('bool')
# create new column
df_crime['indexed'] = (
    df_crime['fbi_index_code']
        .map({True: 'I', False: 'N'})
        .astype(arrow_string)
)

# Create multilevel Index DataFrame
district = df_crime.groupby(['district_location', 'fbi_code_desc', 'indexed']).size()

# get all indexed & non crimes
i_indexed = district.xs('I', level='indexed')
n_indexed = district.xs('N', level=2)
# Display # of Unique District
level_pos = i_indexed.index.names.index('district_location')
print("Unique District:" ,i_indexed.index.levels[level_pos].nunique())
print(f"{'-'*50}")
print(f"Indexed Crime Shape: {i_indexed.shape} & Non-Indexed Crime Shape: {n_indexed.shape}")
# flatten Indexed & Non-Indexed Crimes
i_flat = i_indexed.reset_index(name='count')
n_flat = n_indexed.reset_index(name='count')
print(f"Flatten Indexed Crime Shape: {i_flat.shape} & Flatten Non-Indexed Crime Shape: {n_flat.shape}\n")
# NaNs in District
print('--------------- Missing District Crime ---------------')
mask = df_crime.district_location.isna()
df_crime.loc[mask].groupby(['fbi_code_desc', 'indexed']).size().sort_index(level='indexed')
# Out:
# Unique District: 22
# --------------------------------------------------
# Indexed Crime Shape: (220,) & Non-Indexed Crime Shape: (352,)
# Flatten Indexed Crime Shape: (220, 3) & Flatten Non-Indexed Crime Shape: (352, 3)
#
# --------------- Missing District Crime ---------------
# fbi_code_desc                     indexed
# Larceny – Theft                   I          5
# Miscellaneous Non-Index Offenses  N          3
# Simple Assault                    N          2
# Vandalism                         N          2
# dtype: int64

# %% [markdown]
# ##### District Plot [Jump Back to Summary](#Summary)
# <a id="DistrictPlot"></a>

# %%
# Ready for plot
pivot_district = utils.make_crime_year_crosstab(df_crime,  'district_location', 'fbi_code_desc')
# for plot
melt_district = utils.melt_pivot_for_plotting(pivot_district, 'fbi_code_desc', 'district_location')
# plot
plot.line_plot(melt_district,'fbi_code_desc',  'district_location', 'count')

# %% [markdown]
# #### Indexed Crime

# %%
# plot
data = i_flat
count='count'
indexed='I'
crime_code = 'fbi_code_desc'
column = 'district_location'
# plot
plot.bar_plot(data, count, indexed, crime_code, column)

# %% [markdown]
# #### Non-Indexed Crime

# %%
# plot
data = n_flat
count='count'
indexed='N'
crime_code = 'fbi_code_desc'
column = 'district_location'
# plot
plot.bar_plot(data, count, indexed, crime_code, column)

# %%
# display
column = {"fbi_code_desc": "FBI Crime Type", "district_location": "Police District"}
top_crime(district, True, 1, column)
# Out:
# ------------------------- Top 1 Indexed Crime -------------------------
#
# FBI Crime Type                                Police District
# Aggravated Assault                            Englewood           12,268
# Aggravated Battery                            Harrison            21,611
# Arson                                         Chicago Lawn         1,322
# Burglary                                      Chicago Lawn        39,429
# Criminal Sexual Assault                       Chicago Lawn         3,102
# Homicide – 1st or 2nd Degree                  Harrison             1,429
# Involuntary Manslaughter / Reckless Homicide  Deering                 11
# Larceny – Theft                               Near North         161,621
# Motor Vehicle Theft                           Chicago Lawn        34,879
# Robbery                                       Gresham             23,831
# Name: Incident Count, dtype: object

# %%
# display
top_crime(district, False, 1, column)
# Out:
# ------------------------- Top 1 Non-Indexed Crime -------------------------
#
# FBI Crime Type                           Police District
# Disorderly Conduct                       Chicago Lawn         5,480
# Drug Abuse Violations                    Harrison           138,150
# Embezzlement                             Central                270
# Forgery and Counterfeiting               Central              3,825
# Fraud                                    Near North          32,924
# Gambling                                 Harrison             2,146
# Liquor Laws                              Near West            1,183
# Miscellaneous Non-Index Offenses         Chicago Lawn        37,727
# Offenses Against Family and Children     South Chicago        2,070
# Prostitution                             Harrison            11,505
# Sex Offense – Criminal Sexual Abuse      Chicago Lawn         4,244
# Simple Assault                           South Chicago       40,544
# ...

# %% [markdown]
# #### Neighborhood
# <a id="Neighborhood"></a>

# %%
# display (Ignored)
mask = df_crime.community_name.isna()
# NaNs in District
print('--------------- Missing Neighborhood Crime ---------------')
df_crime.loc[mask].groupby(['fbi_code_desc', 'indexed']).size()
# Out:
# --------------- Missing Neighborhood Crime ---------------
# fbi_code_desc                            indexed
# Aggravated Assault                       I           7951
# Aggravated Battery                       I          16405
# Arson                                    I           1050
# Burglary                                 I          26546
# Criminal Sexual Assault                  I           1922
# Disorderly Conduct                       N           2989
# Drug Abuse Violations                    N          50026
# Embezzlement                             N             98
# Forgery and Counterfeiting               N           2098
# Fraud                                    N          11260
# Gambling                                 N            934
# Homicide – 1st or 2nd Degree             I             87
# Larceny – Theft                          I          96803
# Liquor Laws                              N           1679
# ...

# %%
# Create aggregate and flatten
neighborhood_crime = df_crime.groupby(['community_name', 'fbi_code_desc', 'indexed']).size()
column = {"fbi_code_desc": "FBI Crime Type", "community_name": "Community Name"}
top_crime(neighborhood_crime, True, 1, column)
# Out:
# ------------------------- Top 1 Indexed Crime -------------------------
#
# FBI Crime Type                                Community Name
# Aggravated Assault                            AUSTIN               9,841
# Aggravated Battery                            AUSTIN              15,313
# Arson                                         AUSTIN                 929
# Burglary                                      SOUTH SHORE         18,565
# Criminal Sexual Assault                       AUSTIN               2,836
# Homicide – 1st or 2nd Degree                  AUSTIN               1,173
# Involuntary Manslaughter / Reckless Homicide  BRIGHTON PARK            5
# Larceny – Theft                               NEAR NORTH SIDE    118,738
# Motor Vehicle Theft                           AUSTIN              21,673
# Robbery                                       AUSTIN              21,044
# Name: Incident Count, dtype: object

# %%
top_crime(neighborhood_crime, False, 1, column)
# Out:
# ------------------------- Top 1 Non-Indexed Crime -------------------------
#
# FBI Crime Type                           Community Name
# Disorderly Conduct                       AUSTIN              4,658
# Drug Abuse Violations                    AUSTIN             97,521
# Embezzlement                             NEAR NORTH SIDE       201
# Forgery and Counterfeiting               LOOP                2,513
# Fraud                                    NEAR NORTH SIDE    27,025
# Gambling                                 AUSTIN              2,478
# Liquor Laws                              SOUTH LAWNDALE        798
# Miscellaneous Non-Index Offenses         AUSTIN             30,281
# Offenses Against Family and Children     AUSTIN              1,011
# Prostitution                             AUSTIN              8,488
# Sex Offense – Criminal Sexual Abuse      AUSTIN              2,227
# Simple Assault                           AUSTIN             32,535
# ...

# %% [markdown]
# #### Ward
# <a id="Ward"></a>

# %%
# display (Ignored)
mask = df_crime.ward.isna()
print('--------------- Missing Ward Crime ---------------')
df_crime.loc[mask].groupby(['fbi_code_desc', 'indexed']).size()
# Out:
# --------------- Missing Ward Crime ---------------
# fbi_code_desc                            indexed
# Aggravated Assault                       I           7939
# Aggravated Battery                       I          16385
# Arson                                    I           1047
# Burglary                                 I          26440
# Criminal Sexual Assault                  I           1913
# Disorderly Conduct                       N           2973
# Drug Abuse Violations                    N          49934
# Embezzlement                             N             98
# Forgery and Counterfeiting               N           2078
# Fraud                                    N          11199
# Gambling                                 N            934
# Homicide – 1st or 2nd Degree             I             87
# Larceny – Theft                          I          96431
# Liquor Laws                              N           1679
# ...

# %%
# Create aggregate and flatten
ward_crime = df_crime.groupby(['ward', 'fbi_code_desc', 'indexed']).size()
column = {"fbi_code_desc": "FBI Crime Type", "ward": "Ward"}
top_crime(ward_crime, True, 1, column)
# Out:
# ------------------------- Top 1 Indexed Crime -------------------------
#
# FBI Crime Type                                Ward
# Aggravated Assault                            28        7,060
# Aggravated Battery                            28       13,837
# Arson                                         28          588
# Burglary                                      17       15,503
# Criminal Sexual Assault                       28        1,925
# Homicide – 1st or 2nd Degree                  28          961
# Involuntary Manslaughter / Reckless Homicide  12            7
# Larceny – Theft                               42      161,989
# Motor Vehicle Theft                           06       16,533
# Robbery                                       28       15,697
# Name: Incident Count, dtype: object

# %%
top_crime(ward_crime, False, 1, column)
# Out:
# ------------------------- Top 1 Non-Indexed Crime -------------------------
#
# FBI Crime Type                           Ward
# Disorderly Conduct                       28       3,759
# Drug Abuse Violations                    28      86,319
# Embezzlement                             42         334
# Forgery and Counterfeiting               42       3,592
# Fraud                                    42      36,081
# Gambling                                 28       1,699
# Liquor Laws                              42         649
# Miscellaneous Non-Index Offenses         03      24,985
# Offenses Against Family and Children     06         972
# Prostitution                             28       7,863
# Sex Offense – Criminal Sexual Abuse      02       1,474
# Simple Assault                           28      22,527
# Simple Battery                           28      61,425
# Stolen Property (Buy, Receive, Possess)  02         139
# Vandalism                                28      30,932
# ...

# %% [markdown]
# #### Location Description

# %%
# display (Ignored)
mask = df_crime.location_description.isna()
# NaNs in Location
print('--------------- Missing Crime Location ---------------')
df_crime.loc[mask].groupby(['fbi_code_desc', 'indexed']).size()
# Out:
# --------------- Missing Crime Location ---------------
# fbi_code_desc                            indexed
# Aggravated Assault                       I             17
# Aggravated Battery                       I             30
# Arson                                    I              1
# Burglary                                 I            127
# Criminal Sexual Assault                  I             16
# Disorderly Conduct                       N              3
# Drug Abuse Violations                    N              1
# Forgery and Counterfeiting               N             35
# Fraud                                    N          13905
# Larceny – Theft                          I            786
# Miscellaneous Non-Index Offenses         N             77
# Motor Vehicle Theft                      I              9
# Offenses Against Family and Children     N              2
# Robbery                                  I             29
# ...

# %%
# Create aggregate and flatten
location_description_crime = df_crime.groupby(['location_description', 'fbi_code_desc', 'indexed']).size()
column = {"fbi_code_desc": "FBI Crime Type", "location_description": "Crime Location Description"}
top_crime(location_description_crime, True, 1, column)
# Out:
# ------------------------- Top 1 Indexed Crime -------------------------
#
# FBI Crime Type                                Crime Location Description
# Aggravated Assault                            STREET                         47,526
# Aggravated Battery                            STREET                         60,988
# Arson                                         VEHICLE NON COMMERCIAL          3,929
# Burglary                                      RESIDENCE                     145,720
# Criminal Sexual Assault                       RESIDENCE                      16,470
# Homicide – 1st or 2nd Degree                  STREET                          6,766
# Involuntary Manslaughter / Reckless Homicide  STREET                             80
# Larceny – Theft                               STREET                        484,097
# Motor Vehicle Theft                           STREET                        337,219
# ...

# %%
top_crime(location_description_crime, False, 1, column)
# Out:
# ------------------------- Top 1 Non-Indexed Crime -------------------------
#
# FBI Crime Type                           Crime Location Description
# Disorderly Conduct                       STREET                         26,301
# Drug Abuse Violations                    STREET                        271,584
# Embezzlement                             COMMERCIAL/BUSINESS OFFICE        397
# Forgery and Counterfeiting               RESIDENCE                       9,373
# Fraud                                    RESIDENCE                     102,541
# Gambling                                 SIDEWALK                        8,354
# Liquor Laws                              SIDEWALK                        3,248
# Miscellaneous Non-Index Offenses         RESIDENCE                     163,902
# Offenses Against Family and Children     RESIDENCE                       8,598
# Prostitution                             STREET                         58,390
# ...

# %% [markdown]
# #### Helper Functions

# %%
def top_category(df, sort_col):
    return (
        df.sort_values(["fbi_code_desc", "count"], ascending=[True, False])
          .groupby("fbi_code_desc", as_index=False)
          .first()
          .sort_values(sort_col)
    )

# %%
# Combine
out_tod   = top_category(melt_tod, "time_of_day").drop(columns="count")
out_week  = top_category(melt_week, "day_of_week").drop(columns="count")
out_month = top_category(melt_month, "month").drop(columns="count")
out_qtr   = top_category(melt_qtr, "quarter").drop(columns="count")

out = (
    out_tod
    .merge(out_week,  on="fbi_code_desc", how="left")
    .merge(out_month, on="fbi_code_desc", how="left")
    .merge(out_qtr,   on="fbi_code_desc", how="left")
)
mapping = {
    'Late Night': '12AM - 03AM',
    'Early Morning': '04AM - 07AM',
    'Morning': '08AM - 11AM',
    'Afternoon': '12PM - 03PM',
    'Evening': '04PM - 07PM',
    'Night': '08PM - 11PM'
}

# Add mapping
out['time_of_day'] = out['time_of_day'] + ': ' + out['time_of_day'].map(mapping)

# Build mapping of fbi_code_desc → indexed (I/N)
map_df = (
    df_crime[['fbi_code_desc', 'indexed']]
      .drop_duplicates()
)

# Merge mapping into out
out = out.merge(map_df, on='fbi_code_desc', how='left')

# %% [markdown]
# ### Summary Indexed [Jump Back to Summary](#Summary)
# <a id="Indexed"></a>

# %%
# display all Indexed crie
mask = out.indexed == 'I'
out.loc[mask].iloc[:, :-1].sort_values('fbi_code_desc')
# Out:
#                                    fbi_code_desc              time_of_day  \
# 6                             Aggravated Assault     Evening: 04PM - 07PM
# 24                            Aggravated Battery       Night: 08PM - 11PM
# 13                                         Arson  Late Night: 12AM - 03AM
# 14                                      Burglary     Morning: 08AM - 11AM
# 12                       Criminal Sexual Assault  Late Night: 12AM - 03AM
# 10                  Homicide – 1st or 2nd Degree  Late Night: 12AM - 03AM
# 11  Involuntary Manslaughter / Reckless Homicide  Late Night: 12AM - 03AM
# 3                                Larceny – Theft   Afternoon: 12PM - 03PM
# 20                           Motor Vehicle Theft       Night: 08PM - 11PM
# 22                                       Robbery       Night: 08PM - 11PM
#
#    day_of_week    month quarter
# 6       Sunday     July      Q3
# 24      Sunday     July      Q3
# 13      Sunday     July      Q3
# ...

# %% [markdown]
# ### Summary Non-Indexed [Jump Back to Summary](#Summary)
# <a id="NonIndexed"></a>

# %%
# display all Indexed crie
mask = out.indexed == 'N'
out.loc[mask].iloc[:, :-1].sort_values('fbi_code_desc')
# Out:
#                               fbi_code_desc              time_of_day  \
# 19                       Disorderly Conduct       Night: 08PM - 11PM
# 17                    Drug Abuse Violations       Night: 08PM - 11PM
# 15                             Embezzlement     Morning: 08AM - 11AM
# 4                Forgery and Counterfeiting   Afternoon: 12PM - 03PM
# 5                                     Fraud   Afternoon: 12PM - 03PM
# 8                                  Gambling     Evening: 04PM - 07PM
# 18                              Liquor Laws       Night: 08PM - 11PM
# 2          Miscellaneous Non-Index Offenses   Afternoon: 12PM - 03PM
# 7      Offenses Against Family and Children     Evening: 04PM - 07PM
# 21                             Prostitution       Night: 08PM - 11PM
# 9       Sex Offense – Criminal Sexual Abuse  Late Night: 12AM - 03AM
# 1                            Simple Assault   Afternoon: 12PM - 03PM
# 23                           Simple Battery       Night: 08PM - 11PM
# ...

# %% [markdown]
# #### Calculating the Z-score highlights specialized anomalies—places where a specific crime type is occurring at a rate far beyond what is statistically normal for the rest of the city.
# - A Z-score of 3.0
#     - The value is higher than about 99.87% of all values in a normal distribution
#     - It’s an extreme outlier
# - A Z‑score of 2 means:
#     - The value is higher than about 97.7% of all values in a normal distribution
#     - That year’s count is significantly higher than the historical average
# - A Z-score of -1:
#     - The value is lower than about 84% of all values
#     - It’s a mild decrease, not extreme

# %% [markdown]
# ### Z-score (Heatmap) [Jump Back to Summary](#Summary)
# <a id="Heatmap"></a>

# %%
# Calculate Z Scores
z_df = zscore_anomaly.zscore_anomaly(data=df_crime,time_col='year', category_col='fbi_code_desc')

# Create the Heatmap
plt.figure(figsize=(24, 16))
sns.heatmap(
    z_df,
    cmap="RdBu_r",         # Red for high Z-scores, Blue for low
    center=0,              # White represents the mean
    annot=True,            # Change to False if you don't want to see the numbers
    fmt=".2f",             # format as integers
    annot_kws={"size": 10}, # change font size here
    linewidths=.5
)
plt.title("Point Detailed Summary of Crime Z‑Score Trends (2001–2025)", fontsize=20)
plt.xlabel("Year", fontsize=18)
plt.ylabel("Crime Type", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Save the figure to a file
plt.savefig("../Image/z-score_heatmap.png", dpi=1280, bbox_inches="tight")
plt.show()
